# %% [markdown]
# # Learning Objectives
#
# - [ ]  2.2.2 Use common library functions for input/output, strings and mathematical operations.
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/njc-cz2-2021/Materials/blob/main/365-Days-of-H2-Computing/Day_026.ipynb)

# %% [markdown]
# #### Exercise D28.1
#
# A mathematical equation $y=f(x)$ can be visualized on a cartesian plane as the set of all the points $(x,y)$ where $y=f(x)$. Write a code that
#
# 1. generates 100 points that satisfy the equation $y=x^2$ for $-10\leq x\leq 10$ (for simplicity, take the uniform spacing for the $x$-values of the points),and
# 2. saves them into a text file named `ex8_8.txt`. Each line in the file is of the form $(x,y)$,
# 3. load the points from `ex8_8.txt` and using the module `matplotlib`, show the plot.

# %%
#YOUR_CODE_HERE
import matplotlib



with open("ex8_8.txt","w",newline=""):
    for x,y in range(100):
        print(x,y)
    print("Hello world")
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/base_events.py", line 1919, in _run_once
#     handle._run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/0y/q5jtk39d62j2xwf_8gn4hf100000gn/T/ipykernel_51175/867864421.py", line 2, in <module>
#     import matplotlib
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/__init__.py", line 161, in <module>
#     from . import _api, _version, cbook, _docstring, rcsetup
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/rcsetup.py", line 27, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/colors.py", line 57, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/scale.py", line 22, in <module>
#     from matplotlib.ticker import (
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/ticker.py", line 143, in <module>
#     from matplotlib import transforms as mtransforms
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/transforms.py", line 49, in <module>
#     from matplotlib._path import (
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 2
#       1 #YOUR_CODE_HERE
# ----> 2 import matplotlib
#       6 with open("ex8_8.txt","w",newline=""):
#       7     for x,y in range(100):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/__init__.py:161
#     157 from packaging.version import parse as parse_version
#     159 # cbook must import matplotlib only within function
#     160 # definitions, so it is safe to import from it here.
# --> 161 from . import _api, _version, cbook, _docstring, rcsetup
#     162 from matplotlib.cbook import sanitize_sequence
#     163 from matplotlib._api import MatplotlibDeprecationWarning
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/rcsetup.py:27
#      25 from matplotlib import _api, cbook
#      26 from matplotlib.cbook import ls_mapper
# ---> 27 from matplotlib.colors import Colormap, is_color_like
#      28 from matplotlib._fontconfig_pattern import parse_fontconfig_pattern
#      29 from matplotlib._enums import JoinStyle, CapStyle
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/colors.py:57
#      55 import matplotlib as mpl
#      56 import numpy as np
# ---> 57 from matplotlib import _api, _cm, cbook, scale
#      58 from ._color_data import BASE_COLORS, TABLEAU_COLORS, CSS4_COLORS, XKCD_COLORS
#      61 class _ColorMapping(dict):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/scale.py:22
#      20 import matplotlib as mpl
#      21 from matplotlib import _api, _docstring
# ---> 22 from matplotlib.ticker import (
#      23     NullFormatter, ScalarFormatter, LogFormatterSciNotation, LogitFormatter,
#      24     NullLocator, LogLocator, AutoLocator, AutoMinorLocator,
#      25     SymmetricalLogLocator, AsinhLocator, LogitLocator)
#      26 from matplotlib.transforms import Transform, IdentityTransform
#      29 class ScaleBase:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/ticker.py:143
#     141 import matplotlib as mpl
#     142 from matplotlib import _api, cbook
# --> 143 from matplotlib import transforms as mtransforms
#     145 _log = logging.getLogger(__name__)
#     147 __all__ = ('TickHelper', 'Formatter', 'FixedFormatter',
#     148            'NullFormatter', 'FuncFormatter', 'FormatStrFormatter',
#     149            'StrMethodFormatter', 'ScalarFormatter', 'LogFormatter',
#    (...)
#     155            'MultipleLocator', 'MaxNLocator', 'AutoMinorLocator',
#     156            'SymmetricalLogLocator', 'AsinhLocator', 'LogitLocator')
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/transforms.py:49
#      46 from numpy.linalg import inv
#      48 from matplotlib import _api
# ---> 49 from matplotlib._path import (
#      50     affine_transform, count_bboxes_overlapping_bbox, update_path_extents)
#      51 from .path import Path
#      53 DEBUG = False
#
# ImportError: numpy.core.multiarray failed to import

# %% [markdown]
# #### Exercise D28.2
#
# A text file, `NOI_24_RESULT.txt` contains the results of the medallist recipients for the 24th National Olympiad in Informatics.
#
# Write a code to:
#
# - read the data from the text file,
# - store the school name and medal counts in a Python dictionary `medal_count` where the school name is the key and the associated value is a tuple of the form `(GOLD, SILVER, BRONZE)`,
# - print out the top 5 school with the highest number of medals won, regardless of the medal type.

# %%
#YOUR_CODE_HERE
import csv

with open("/Users/openplayer/Documents/GitHub/2026_cz2a_repo/365-Days-of-H2-Computing/resources/NOI_24_RESULT.csv",'r') as file:
    reader = csv.DictReader(file)
    for line in reader:
        print(line)
# Out:
# {'Gold': '1.Au Heng Hoi', None: [' Joel', ' NUS High School Of Mathematics And Science']}
# {'Gold': '2.Evan Lim Hong Jun', None: [' Raffles Institution']}
# {'Gold': '3.Huang Qirui', None: [' Hwa Chong Institution']}
# {'Gold': '4.Jamie Lim Jia Sin (Lin Jiaxin)', None: [' NUS High School Of Mathematics And Science']}
# {'Gold': '5.Kang Yiming', None: [' Raffles Institution']}
# {'Gold': '6.Shen Zihan', None: [' National Junior College']}
# {'Gold': '7.Sng James (Sun Jie)', None: [' NUS High School Of Mathematics And Science']}
# {'Gold': '8.Song Yiyang', None: [' Raffles Institution']}
# {'Gold': '9.Soumyaditya Choudhuri', None: [' United World College South East Asia Dover Campus']}
# {'Gold': '10.Stuart Lim Yi Xiong', None: [' Hwa Chong Institution']}
# {'Gold': '11.Tan Yi Kai', None: [' Hwa Chong Institution']}
# {'Gold': '12.Wang Yunrui', None: [' Raffles Institution']}
# {'Gold': '13.Yaw Chur Zhe', None: [' Hwa Chong Institution']}
# {'Gold': '14.Zeng Minghao', None: [' Manjusri Secondary School']}
# {'Gold': '15.Zhao Zhongqi', None: [' Hwa Chong Institution']}
# {'Gold': '16.Yu Zheyuan', None: [' NUS High School Of Mathematics And Science']}
# {'Gold': 'Silver'}
# {'Gold': '1.Adhitya Polavaram', None: [' Singapore American School']}
# {'Gold': '2.Advay Ratan', None: [' Singapore American School']}
# {'Gold': '3.Baghaskara Pandya Narayana', None: [' DPS International School']}
# {'Gold': '4.Benedict Tan Deng Jin', None: [' NUS High School Of Mathematics And Science']}
# {'Gold': '5.Brian Lee Jun Siang', None: [' Hwa Chong Institution']}
# {'Gold': '6.Cao Jia Lin', None: [' Marianna', ' National Junior College']}
# {'Gold': '7.Chang Yung Chiang', None: [' Anderson Serangoon Junior College']}
# {'Gold': '8.Cheng Haoyang', None: [' Anglo-Chinese School Independent']}
# {'Gold': '9.Cheung Ho Fai Brandon', None: [' Yishun Innova Junior College']}
# {'Gold': '10.Cui Yihan', None: [" CHIJ St. Nicholas Girls' School"]}
# {'Gold': '11.Dylan Michael Chong', None: [' Anglo-Chinese School Independent']}
# {'Gold': '12.Dylan See Yuzhi', None: [' Dunman High School']}
# {'Gold': '13.Feilin Liangga Putri', None: [" Methodist Girls' School Secondary"]}
# {'Gold': '14.Gabriel Mario Antaputra', None: [' Anglo-Chinese Junior College']}
# {'Gold': '15.Gao Yihe', None: [' National Junior College']}
# {'Gold': '16.Goh Yu Shen', None: [' Catholic High School']}
# {'Gold': '17.Gu Yingqi', None: [' River Valley High School']}
# {'Gold': '18.Harsha Polavaram', None: [' Singapore American School']}
# {'Gold': '19.Huang Keyi', None: [' Raffles Institution']}
# {'Gold': '20.Huang Ziwen', None: [' Raffles Institution']}
# {'Gold': '21.James Tan Dejun', None: [' River Valley High School']}
# {'Gold': '22.Javier Lim', None: [' NUS High School Of Mathematics And Science']}
# {'Gold': '23.Jiang Tongyu', None: [" Raffles Girls' School Secondary"]}
# {'Gold': '24.Jishnu Roychoudhury', None: [' United World College South East Asia Dover Campus']}
# {'Gold': '25.Jordan Low Jin Yi', None: [' Nanyang Junior College']}
# {'Gold': '26.Justin Park', None: [' United World College South East Asia Dover Campus']}
# {'Gold': '27.Kiew Tian Le', None: [' Ernest', ' Anderson Secondary School']}
# {'Gold': '28.Koh Jia Hng', None: [' Raffles Institution']}
# {'Gold': '29.Lam Yik Ting', None: [' Dunman High School']}
# {'Gold': '30.Le Duc Minh', None: [' Bukit Panjang Govt. High School']}
# {'Gold': '31.Le Tran Cong Hung', None: [' Anglo-Chinese School Independent']}
# {'Gold': '32.Le Tu Quoc Dat', None: [' Tampines Meridian Junior College']}
# {'Gold': '33.Lee Jing Peng', None: [' River Valley High School']}
# {'Gold': '34.Leo Qiyi Joel', None: [' Dunman High School']}
# {'Gold': '35.Low Choo Ray', None: [' Raffles Institution']}
# {'Gold': '36.Luo Jiale', None: [' National Junior College']}
# {'Gold': '37.Luo Qiuyi', None: [' Ngee Ann Secondary School']}
# {'Gold': '38.Mohammad Suhail Memon Loya', None: [' Global Indian International School']}
# {'Gold': '39.Ng Mun Hin', None: [' Raffles Institution']}
# {'Gold': '40.Nguyen Cao Duy', None: [' Anderson Serangoon Junior College']}
# {'Gold': '41.Nguyen Duc Minh Anh', None: [" St. Joseph's Institution"]}
# {'Gold': '42.Nguyen Ngoc Quyet', None: [' Swiss Cottage Secondary School']}
# {'Gold': '43.Nguyen Phuc Chuong', None: [" St. Joseph's Institution"]}
# {'Gold': '44.Nguyen Thai Binh', None: [' Ngee Ann Secondary School']}
# {'Gold': '45.Ong Jia Cheng', None: [' Anglo-Chinese Junior College']}
# {'Gold': '46.Pran Tanprasertkul', None: [' Anderson Secondary School']}
# {'Gold': '47.Ryan Goh Choon Aik', None: [' Raffles Institution']}
# {'Gold': '48.Seojun Lee', None: [' United World College South East Asia Dover Campus']}
# {'Gold': '49.Si Wen Xuan', None: [' Terry', ' Hwa Chong Institution']}
# {'Gold': '50.Subramanian Ramasamy', None: [' NUS High School Of Mathematics And Science']}
# {'Gold': '51.Taha Ebrahim', None: [' United World College South East Asia Dover Campus']}
# {'Gold': '52.Tan Swee Kang', None: [' River Valley High School']}
# {'Gold': '53.Tia Shi Wei', None: [' NUS High School Of Mathematics And Science']}
# {'Gold': '54.Tung Ivan Kipling', None: [' Hwa Chong Institution']}
# {'Gold': '55.Vayun Mathur', None: [' Singapore American School']}
# {'Gold': '56.Vir Chaudhury', None: [' United World College South East Asia Dover Campus']}
# {'Gold': '57.Wang Yihe', None: [' Hwa Chong Institution']}
# {'Gold': '58.Yang Lihan', None: [' Nanyang Junior College']}
# {'Gold': '59.Yanjia Zhang', None: [' United World College South East Asia Dover Campus']}
# {'Gold': '60.Yap Yuan Xi', None: [' NUS High School Of Mathematics And Science']}
# {'Gold': '61.Yeo Bing Lin', None: [' Hwa Chong Institution']}
# {'Gold': 'Bronze'}
# {'Gold': '1.Aron Septianto', None: [' Anglo-Chinese School Independent']}
# {'Gold': '2.Cadence Wern Sea Loh', None: [" Raffles Girls' School Secondary"]}
# {'Gold': '3.David Walton', None: [' United World College South East Asia Dover Campus']}
# {'Gold': '4.Devansh Shah', None: [' Global Indian International School']}
# {'Gold': '5.Divyesh Balakrishnan', None: [' Clementi Town Secondary School']}
# {'Gold': '6.Hein Htet Zaw', None: [' Commonwealth Secondary School']}
# {'Gold': '7.Jiang Tianyuan', None: [' Dunman High School']}
# {'Gold': '8.Jiao Pengtao', None: [' Victoria School']}
# {'Gold': '9.Jonathan Tan Jiayi', None: [' School Of Science And Technology', ' Singapore']}
# {'Gold': '10.Lim Yan Khai Bennett', None: [' Anglo-Chinese School Independent']}
# {'Gold': '11.Luo Jiaqi', None: [" St. Joseph's Institution"]}
# {'Gold': '12.Ma Xundong', None: [' Hwa Chong International School']}
# {'Gold': '13.Ng Yu Ray', None: [' Commonwealth Secondary School']}
# {'Gold': '14.Ryan Lee Yew Keene', None: [' Temasek Junior College']}
# {'Gold': '15.Thai Le Minh Hoai', None: [' Anderson Serangoon Junior College']}
# {'Gold': '16.Vincent Lim Jing En', None: [' Temasek Junior College']}
# {'Gold': '17.Vishal Mohanty', None: [' NUS High School Of Mathematics And Science']}

# %% [markdown]
# #### Exercise D28.3
#
# A text file, `MARKET_PRICES.TXT`, contains the in-game prices for 6 items, Widowbloom, Rising Glory, Marrowroot, Vigil's Torch, Nighshade and Spectral Flask of Power from 1 December 2020 to 3 March 2021. Each line contains tab-delimited data that shows the date and the prices (in copper coins) of the 6 items.
#
# Each line is in the format:
#
#     `YYYY-MM-DD\tWIDOWBLOOM\tRISING_GLORY\t\MARROWROOT\tVIGILS_TORCH\tNIGHTSHADE\tSPECTRAL_FLASK_OF_POWER\n`
#
# - The date is of the form `YYYY-MM-DD`, for example, `2020-12-03` is 3rd December, 2020.
# - WIDOWBLOOM, RISING_GLORY, MARROWROOT, VIGILS_TORCH, NIGHTSHADE, SPECTRAL_FLASK_OF_POWER are all integers.
# - `\t` represents the tab character
# - `\n` represents the newline character
#
# The text file is stored in ascending order of date and time.
#
# ##### Task 1
#
# Write a program to:
#
# - read the price data from the text file,
# - for each of the 6 items:
#     - find the highest price and print this value,
#     - find the lowest price and print this value.
#
# ##### Task 2
#
# Suppose you want to play the market by buying and selling the 6 items above, one way to decide on items to invest in is by using the mean and variance of the daily rate of returns of the items. The latter is used to quantify the risk of holding such item.
#
# For an item $j$,
# - the **daily rate of return** of day $i$ to $i+1$, denoted as $r_i$ is defined to be $$r_i=\frac{p_{i+1}-p_{i}}{p_i},$$ where $p_{i+1}$ and $p_i$ are prices of the item on day $i+1$ and day $i$ respectively,
# - the mean of the daily rate of returns, denoted as $\overline{r}$, is just $\frac{\sum r_i}{n}$, where $n$ is the number of daily rate of returns recorded,
# - the variance of the daily rate of returns is $$\frac{\sum{(r_i-\overline{r})^2}}{n},$$ where $\overline{r}$ is the mean of the daily rate of returns and again $n$ is the number of daily returns recorded.
#
# Write a program to:
#
# - for each of the 6 items:
#     - find the mean of the daily rate of return,
#     - find the variance of the daily rate of return.

# %%
#YOUR_CODE_HERE
